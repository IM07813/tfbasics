# %% [markdown]
# #Working with pandas for data analysis
#
# ##data used is gathered from zameen.com and consist of realestate price in pakistan

# %%
import pandas as pd 
#to read from a csv file do pd.read_csv('')
#to read from an excel file do pd.read_excel('')

df = pd.read_csv('/content/drive/MyDrive/Property_with_Feature_Engineering.csv')
df.head()
#to create a new dataframe 
new_df = pd.DataFrame(columns = ['one_column'])
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#    price_bin           location    city province_name  \
# 0  Very High         Model Town  Lahore        Punjab
# 1  Very High        Multan Road  Lahore        Punjab
# 2        Low               Eden  Lahore        Punjab
# 3  Very High            Gulberg  Lahore        Punjab
# ...

# %%
#read headers
print(df.columns)
# Out:
# Index(['property_id', 'location_id', 'page_url', 'property_type', 'price',
#        'price_bin', 'location', 'city', 'province_name', 'locality',
#        'latitude', 'longitude', 'baths', 'area', 'area_marla', 'area_sqft',
#        'purpose', 'bedrooms', 'date_added', 'year', 'month', 'day', 'agency',
#        'agent'],
#       dtype='object')

# %%
#read a specific column 
print(df['location_id'])
# Out:
# 0            8
# 1           48
# 2           75
# 3         3821
# 4         3522
#           ...
# 191388     174
# 191389     174
# 191390     167
# 191391     339
# 191392    3421
# Name: location_id, Length: 191393, dtype: int64

# %%
#read each row
print(df.iloc[1:2])
# Out:
#    property_id  location_id  \
# 1       482892           48
#
#                                             page_url property_type     price  \
# 1  https://www.zameen.com/Property/lahore_multan_...         House  40000000
#
#    price_bin     location    city province_name                     locality  \
# 1  Very High  Multan Road  Lahore        Punjab  Multan Road, Lahore, Punjab
#
#    ...  area_marla  area_sqft   purpose bedrooms  date_added  year month  day  \
# 1  ...        20.0    5445.02  For Sale        5  10-06-2018  2018    10    6
#
#         agency             agent
# 1  Khan Estate  mohsinkhan and B
#
# [1 rows x 24 columns]

# %%
#read a specific location (rowsxcolumns)
print(df.iloc[2,1])
# Out:
# 75

# %%
#to find specific results inside a column
#for example
df.loc[df['location_id'] == 8]
# Out:
#         property_id  location_id  \
# 0            347795            8
# 97          4940629            8
# 1218        8067446            8
# 2045        8267197            8
# 3192        8803462            8
# ...             ...          ...
# 190984     17462525            8
# 191042     17464143            8
# 191043     17464184            8
# 191044     17464211            8
# 191199     17467662            8
#
#                                                  page_url  property_type  \
# 0       https://www.zameen.com/Property/lahore_model_t...          House
# 97      https://www.zameen.com/Property/lahore_model_t...          House
# 1218    https://www.zameen.com/Property/lahore_model_t...          House
# 2045    https://www.zameen.com/Property/lahore_model_t...          House
# 3192    https://www.zameen.com/Property/lahore_model_t...          House
# ...                                                   ...            ...
# ...

# %%
#sorting/describing data
df.describe()
# Out:
#         property_id    location_id         price       latitude  \
# count  1.913930e+05  191393.000000  1.913930e+05  191393.000000
# mean   1.573170e+07    4224.580350  1.644655e+07      30.104593
# std    2.215249e+06    3719.125201  3.416412e+07       3.645941
# min    8.657500e+04       1.000000  0.000000e+00      11.052446
# 25%    1.511867e+07    1057.000000  8.000000e+04      24.972287
# 50%    1.676385e+07    3233.000000  7.300000e+06      31.463563
# 75%    1.715282e+07    7182.000000  1.800000e+07      33.550869
# max    1.769386e+07   14246.000000  2.000000e+09      73.184088
#
#            longitude          baths     area_marla     area_sqft  \
# count  191393.000000  191393.000000  191393.000000  1.913930e+05
# mean       71.572992       2.865956      14.573527  3.967656e+03
# std         3.080463       2.435332     443.343252  1.207006e+05
# min        25.906027       0.000000       0.000000  0.000000e+00
# ...

# %%
#sorting location_id by decending order:
df.sort_values(['location_id'], ascending=False)
# Out:
#         property_id  location_id  \
# 182983     17395040        14246
# 182988     17395066        14246
# 189614     17446840        14231
# 175413     17338444        14220
# 175404     17338284        14220
# ...             ...          ...
# 29413      13852742            4
# 55012      15508073            3
# 59520      15669851            2
# 94458      16748132            1
# 48674      15180638            1
#
#                                                  page_url  property_type  \
# 182983  https://www.zameen.com/Property/lahore_sheikhu...          House
# 182988  https://www.zameen.com/Property/lahore_sheikhu...          House
# 189614  https://www.zameen.com/Property/lahore_abid_ro...  Lower Portion
# 175413  https://www.zameen.com/Property/scheme_33_stat...           Flat
# 175404  https://www.zameen.com/Property/scheme_33_stat...           Flat
# ...                                                   ...            ...
# ...

# %%
#let's make some changes to the data
#creating a new column
df['Total'] = df['location_id']
df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#    price_bin           location    city province_name  \
# 0  Very High         Model Town  Lahore        Punjab
# 1  Very High        Multan Road  Lahore        Punjab
# 2        Low               Eden  Lahore        Punjab
# 3  Very High            Gulberg  Lahore        Punjab
# ...

# %%
#to drop a column
df = df.drop(columns=['Total'])

df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#    price_bin           location    city province_name  \
# 0  Very High         Model Town  Lahore        Punjab
# 1  Very High        Multan Road  Lahore        Punjab
# 2        Low               Eden  Lahore        Punjab
# 3  Very High            Gulberg  Lahore        Punjab
# ...

# %%
df = df.drop(columns = ['agency'])

# %%
#droped agency and agent columns 
df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#    price_bin           location    city province_name  \
# 0  Very High         Model Town  Lahore        Punjab
# 1  Very High        Multan Road  Lahore        Punjab
# 2        Low               Eden  Lahore        Punjab
# 3  Very High            Gulberg  Lahore        Punjab
# ...

# %%
#to save it inside a csv file
#df.to_csv('nameofdata.csv')

# %%
#using operators to filter data
df.loc[(df['location_id'] == 8) & (df['baths']== 5)]
# Out:
#         property_id  location_id  \
# 12179      11489683            8
# 20920      12767148            8
# 28471      13776122            8
# 37347      14452502            8
# 38732      14575826            8
# ...             ...          ...
# 178890     17351799            8
# 187607     17431614            8
# 188268     17442651            8
# 191042     17464143            8
# 191043     17464184            8
#
#                                                  page_url property_type  \
# 12179   https://www.zameen.com/Property/lahore_model_t...         House
# 20920   https://www.zameen.com/Property/lahore_model_t...         House
# 28471   https://www.zameen.com/Property/lahore_model_t...         House
# 37347   https://www.zameen.com/Property/lahore_model_t...         House
# 38732   https://www.zameen.com/Property/lahore_model_t...         House
# ...                                                   ...           ...
# ...

# %%
# pandas & operator 
# pandas | operator(or)

df.loc[(df['location_id'] == 8) | (df['location_id'] == 9) | (df['location_id'] < 2)]
# Out:
#         property_id  location_id  \
# 0            347795            8
# 97          4940629            8
# 658          411001            9
# 659          411006            9
# 660          411012            9
# ...             ...          ...
# 190984     17462525            8
# 191042     17464143            8
# 191043     17464184            8
# 191044     17464211            8
# 191199     17467662            8
#
#                                                  page_url  property_type  \
# 0       https://www.zameen.com/Property/lahore_model_t...          House
# 97      https://www.zameen.com/Property/lahore_model_t...          House
# 658     https://www.zameen.com/Property/lahore_dha_def...          House
# 659     https://www.zameen.com/Property/lahore_dha_def...          House
# 660     https://www.zameen.com/Property/lahore_dha_def...          House
# ...                                                   ...            ...
# ...

# %%
#using conditional if statements
df2 = df.loc[df['location_id'] <=9 ,'new_column with id location less than 9'] = 'True'
df2
# Out:
# 'True'

# %%
df3 = df['equal_or_lower_than_4?'] = df['location_id'].apply(lambda x: 'True' if x <= 8 else 'False')
df3
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 191388    False
# 191389    False
# 191390    False
# 191391    False
# 191392    False
# Name: location_id, Length: 191393, dtype: object

# %% [markdown]
# ##IF condition – strings
#
# Now, let’s create a DataFrame that contains only strings/text with 2 cities names lahore and islamabad

# %%
df.loc[df['city'] == 'Lahore', 'name_match'] = 'Match'  
df.loc[df['city'] != 'Lahore', 'name_match'] = 'Mismatch' 
df
# Out:
#         property_id  location_id  \
# 0            347795            8
# 1            482892           48
# 2            555962           75
# 3            562843         3821
# 4            686990         3522
# ...             ...          ...
# 191388     17468383          174
# 191389     17468384          174
# 191390     17468482          167
# 191391     17468586          339
# 191392     17468660         3421
#
#                                                  page_url  property_type  \
# 0       https://www.zameen.com/Property/lahore_model_t...          House
# 1       https://www.zameen.com/Property/lahore_multan_...          House
# 2       https://www.zameen.com/Property/eden_eden_aven...          House
# 3       https://www.zameen.com/Property/gulberg_2_gulb...          House
# 4       https://www.zameen.com/Property/allama_iqbal_t...          House
# ...                                                   ...            ...
# ...

# %%
#seeing the max and min values
df['price'].max()
# Out:
# 2000000000

# %%
#for the min price 
df['price'].min()
# Out:
# 0

# %%
df.loc[df['price'] == 0]
# Out:
#         property_id  location_id  \
# 70880      16081186         8129
# 97464      16786134        12395
# 140353     17122202         1058
#
#                                                  page_url property_type  \
# 70880   https://www.zameen.com/Property/rawalpindi_ran...         House
# 97464   https://www.zameen.com/Property/karachi_gadap_...    Farm House
# 140353  https://www.zameen.com/Property/rawalpindi_gul...         House
#
#         price price_bin      location        city province_name  \
# 70880       0       Low    Range Road  Rawalpindi        Punjab
# 97464       0       Low    Gadap Road     Karachi         Sindh
# 140353      0       Low  Gulshan Abad  Rawalpindi        Punjab
#
#                                 locality  ...  area_sqft   purpose  bedrooms  \
# 70880     Range Road, Rawalpindi, Punjab  ...    1361.25  For Rent         0
# 97464         Gadap Road, Karachi, Sindh  ...   43560.16  For Sale         0
# ...

# %%
#dropping all the rows with price == 0 
df.drop(df[df['price'] == 0].index, inplace = True)

# %%
df.loc[df['price'] == 0]
# Out:
# Empty DataFrame
# Columns: [property_id, location_id, page_url, property_type, price, price_bin, location, city, province_name, locality, latitude, longitude, baths, area, area_marla, area_sqft, purpose, bedrooms, date_added, year, month, day, new_column with id location less than 9, equal_or_lower_than_4?, name_match]
# Index: []
#
# [0 rows x 25 columns]

# %%
#working with large amount of datasets
#you can read a file in batches 
df = pd.read_csv('nameoffile.csv', chunksize = 5) #means 5 rows are being passed one at a time
